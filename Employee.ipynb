# %%
import pandas as pd
df= pd.read_csv('emp.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df['First Name']=df['First Name'].fillna('NA')

# %%
df['First Name'].sample(20)
# Out:
# 506     Donald
# 153     Victor
# 663     Andrea
# 72       Bobby
# 398      Doris
# 476      Kathy
# 336       Mark
# 600    Barbara
# 771      Peter
# 113       Tina
# 176     Victor
# 401      Norma
# 20        Lois
# 693      Alice
# 569       Ruby
# 709         NA
# 312     Gerald
# 797       Rose
# 97       Laura
# 672     Robert
# Name: First Name, dtype: object

# %%
df['First Name']=df['First Name'].replace(to_replace='NA',value='Not Known')
df['First Name'].sample(20)
# Out:
# 602        Bobby
# 50         Nancy
# 337         Earl
# 396         Rose
# 161      Marilyn
# 588      Cynthia
# 481    Not Known
# 574    Not Known
# 988        Alice
# 420       Justin
# 958       Gloria
# 847       Nicole
# 656         Lisa
# 62     Not Known
# 121     Kathleen
# 331       Evelyn
# 571     Jonathan
# 798     Lawrence
# 651      Deborah
# 921       George
# Name: First Name, dtype: object

# %%
df.sample(50)
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 531    Virginia  Female    5/2/2010         9:10 PM  123649   10.154
# 361    Margaret  Female    5/5/2014         6:01 AM   55044    4.078
# 514         Amy     NaN  12/25/1984        10:52 AM   63888   18.115
# 650     Cynthia  Female    7/5/1986         1:24 AM   35381   11.749
# 890   Not Known    Male  11/24/2015         3:11 AM  145329    7.100
# 296      Jeremy     NaN  11/10/1996         1:49 PM   55394    3.180
# 577       Jerry    Male    5/4/2003         4:29 AM   98393   11.393
# 693       Alice  Female  10/16/1995         9:19 PM   92799    2.782
# 967      Thomas    Male   3/12/2016         3:10 PM  105681   19.572
# 604       Bruce    Male   3/15/2013        11:13 PM  141335   15.427
# 269   Not Known  Female    8/2/1992         8:35 PM  145316   18.517
# 772     Lillian  Female   8/14/2009         5:41 AM  113554   18.018
# 73      Frances  Female    4/4/1999         4:19 PM   90582    4.709
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Salary'],df['Bonus'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='Salary',y='Bonus',data=df,hue='Team')
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus'>

# %%
sns.pairplot(df)

# %%
import ydata_profiling
from ydata_profiling import ProfileReport
a=ProfileReport(df)
a.to_file('a.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.head(1)
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308  6.945
#
#   Senior Management       Team
# 0              True  Marketing

# %%
x= df[['Salary']]

# %%
y=df['Bonus']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train.shape
# Out:
# (750, 1)

# %%
x_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
mukesh=LinearRegression()

# %%
#Training Models
mukesh.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mukesh.predict(x_test)

# %%
mukesh.predict([[61933]])
# Out:
# C:\Users\Rakesh IBM\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.4895214])

# %%
#coefficient (c)
mukesh.intercept_
# Out:
# 11.002892470197404

# %%
#slope (m)
mukesh.coef_
# Out:
# array([-8.28913614e-06])

# %%
from sklearn.metrics import  r2_score,mean_squared_error
r2_score(y_test,y_pred)
# Out:
# -0.003896961072827221

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 31.20012162711187

# %%
#df[['Salary']]
#df['Bonus']
mukesh.predict(df[['Salary']])
# Out:
# array([10.19629321, 10.4895214 ,  9.92041418,  9.85314784, 10.16565656,
#        10.04829069, 10.46015299, 10.62237139, 10.21069973,  9.8436402 ,
#        10.47867921, 10.1531897 , 10.06781989, 10.09248836, 10.65950672,
#        10.51040174, 10.25380324, 10.07668927,  9.90093471, 10.3313564 ,
#        10.46646931, 10.16890591, 10.25010628,  9.96018546, 10.19097159,
#        10.69556446, 10.69123753,  9.98857575,  9.97497328, 10.34366576,
#        10.01830888, 10.26800253,  9.98879956, 10.01580556, 10.20934031,
#        10.29680728,  9.82556989, 10.52687225, 10.69748754,  9.99018384,
#        10.17992217, 10.45098521,  9.99229757, 10.39344202,  9.79975752,
#        10.2733656 , 10.0513328 , 10.44901239, 10.22718682, 10.0613295 ,
#        10.21562348, 10.66199346, 10.59391478, 10.66850043, 10.30928243,
#        10.15335549,  9.92301697, 10.46646103, 10.40052095, 10.44875543,
#        10.59783554, 10.1170988 , 10.52119419, 10.71109001, 10.35771585,
# ...
