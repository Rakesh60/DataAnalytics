# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv('premium.csv')

# %%
df
# Out:
#    Age  height  weight  Premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    32000
# 2   35  167.64      78    40000
# 3   40  165.10     110    47000
# 4   45  157.48      85    55000

# %%
df.head()
# Out:
#    Age  height  weight  Premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    32000
# 2   35  167.64      78    40000
# 3   40     NaN     110    47000
# 4   45  157.48      85    55000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      5 non-null      int64
#  1   height   4 non-null      float64
#  2   weight   5 non-null      int64
#  3   Premium  5 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#              Age      height      weight       Premium
# count   5.000000    5.000000    5.000000      5.000000
# mean   35.000000  165.100000   87.600000  38400.000000
# std     7.905694    5.679613   15.533834  14223.220451
# min    25.000000  157.480000   70.000000  18000.000000
# 25%    30.000000  162.560000   78.000000  32000.000000
# 50%    35.000000  165.100000   85.000000  40000.000000
# 75%    40.000000  167.640000   95.000000  47000.000000
# max    45.000000  172.720000  110.000000  55000.000000

# %%
#sns.lmplot(x='weight',y='Premium',data=df)

# %%
#For filling Empty cells in height
mean_height=df.height.mean()
#df.height.fillna(m_h,inplace=True)
df.height=df.height.fillna(mean_height)

# %%
df
# Out:
#    Age  height  weight  Premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    32000
# 2   35  167.64      78    40000
# 3   40  165.10     110    47000
# 4   45  157.48      85    55000

# %%
model=linear_model.LinearRegression()
model.fit(df[['Age','height','weight']],df['Premium'])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2009.46501319,  501.71220028,  -56.72906086])

# %%
model.intercept_
# Out:
# -109794.49399687728

# %%
model.predict([[45,157.48,85]])
# Out:
# C:\Users\rakesh\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([54819.098724])

# %%
model.score(df[['Age','height','weight']],df['Premium'])
# Out:
# 0.9997870898053338

# %%
model.predict([[35,167.64,78]])
# Out:
# C:\Users\rakesh\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40218.94797294])

# %%
model.predict(df[['Age','height','weight']])
# Out:
# array([18029.43235046, 31755.92684984, 40218.94797294, 47176.59410276,
#        54819.098724  ])
