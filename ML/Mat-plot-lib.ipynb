# %%
import matplotlib.pyplot as plt
import numpy as np
width=0.2
p=np.arange(len(x))
p1=[j+0.2 for j in p]

x=['Python','Java','C/C++','Javascript']
y=[85,70,60,90]
z=[20,30,40,50]

#plt.bar(x,y,color=['m','r','y','b'],edgecolor='g',linewidth=5,linestyle=':',alpha=0.5)
plt.barh(p,y,width,color='r',label='popularity')
plt.barh(p1,z,width,color='y',label='popularity1')

plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.title('Programming Lang' ,fontsize=10)

#plt.xticks(p+0.2/2,x,rotation=20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
